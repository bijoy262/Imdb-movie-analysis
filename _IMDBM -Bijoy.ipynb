# %% [markdown]
# # IMDb Movie

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %% [markdown]
# **Read the Movies Data**

# %%
movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ** Inspect the Dataframe**

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
movies.dtypes
# Out:
# Title              object
# title_year          int64
# budget              int64
# Gross               int64
# actor_1_name       object
#                    ...
# Votes1000         float64
# VotesUS           float64
# VotesnUS          float64
# content_rating     object
# Country            object
# Length: 62, dtype: object

# %%
movies.shape
# Out:
# (100, 62)

# %% [markdown]
# **Summary of numeric movies**

# %%
numerics = ['int16', 'int32', 'int64','float']
num=movies.select_dtypes(include=numerics)
num
# Out:
#     title_year     budget      Gross  actor_1_facebook_likes  \
# 0         2016   30000000  151101803                   14000
# 1         2016  150000000  341268248                    2800
# 2         2016   12000000   51738905                   33000
# 3         2016   47000000  100546139                   35000
# 4         2016    9000000   47695371                     518
# ..         ...        ...        ...                     ...
# 95        2014    3300000   13092000                   24000
# 96        2013    3000000    8114507                     140
# 97        2015  245000000  936662225                     131
# 98        2010  150000000  296347721                   10000
# 99        2010    5000000     223838                     948
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  MetaCritic  \
# 0                  19000.0                     NaN          8.2        93.0
# 1                  28000.0                 27000.0          8.1        78.0
# ...

# %% [markdown]
#   **DATA CLEANING**

# %%
movies.isna().sum().sort_values()
# Out:
# Title                      0
# CVotes1829F                0
# CVotes3044                 0
# CVotes3044M                0
# CVotes3044F                0
#                           ..
# actor_2_facebook_likes     1
# actor_3_facebook_likes     2
# genre_2                    3
# MetaCritic                 5
# genre_3                   26
# Length: 62, dtype: int64

# %%
movies.MetaCritic=movies.MetaCritic.fillna(0)

# %%
movies['actor_3_facebook_likes']=movies['actor_3_facebook_likes'].fillna(0)

# %%
movies['actor_2_facebook_likes']=movies['actor_2_facebook_likes'].fillna(0)

# %%
movies['genre_2'].head(20)
# Out:
# 0         Drama
# 1     Adventure
# 2         Drama
# 3       Mystery
# 4           NaN
# 5         Drama
# 6     Adventure
# 7     Adventure
# 8      Thriller
# 9     Adventure
# 10      Fantasy
# 11       Sci-Fi
# 12    Adventure
# 13    Adventure
# 14    Adventure
# 15    Adventure
# 16      Fantasy
# 17    Adventure
# 18    Adventure
# 19    Adventure
# Name: genre_2, dtype: object

# %%
movies.isna().sum().sort_values()
# Out:
# Title           0
# CVotes1829F     0
# CVotes3044      0
# CVotes3044M     0
# CVotes3044F     0
#                ..
# CVotesU18       0
# CVotes10        0
# Country         0
# genre_2         3
# genre_3        26
# Length: 62, dtype: int64

# %%
numerics = ['int16', 'int32', 'int64','float']
num=movies.select_dtypes(include=numerics)
num
# Out:
#     title_year     budget      Gross  actor_1_facebook_likes  \
# 0         2016   30000000  151101803                   14000
# 1         2016  150000000  341268248                    2800
# 2         2016   12000000   51738905                   33000
# 3         2016   47000000  100546139                   35000
# 4         2016    9000000   47695371                     518
# ..         ...        ...        ...                     ...
# 95        2014    3300000   13092000                   24000
# 96        2013    3000000    8114507                     140
# 97        2015  245000000  936662225                     131
# 98        2010  150000000  296347721                   10000
# 99        2010    5000000     223838                     948
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  MetaCritic  \
# 0                  19000.0                     0.0          8.2        93.0
# 1                  28000.0                 27000.0          8.1        78.0
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ** Reduce those Digits!**

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'

# %%
movies.budget=movies.budget.apply(lambda x :x/1000000)

# %%
movies.Gross=movies.Gross.apply(lambda x :x/1000000)

# %%
movies.head(5)
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %% [markdown]
# **Subtask 2.2  Let's Talk Profit!   PROFIT Top ten movie list  using sorting function**

# %%
movies['profit']=movies.Gross-movies.budget

# %%
fifth_pos=movies.pop("profit")
movies.insert(4,'profit',fifth_pos)

# %%
movies.head(5)
# Out:
#                    Title  title_year  budget       Gross      profit  \
# 0             La La Land        2016    30.0  151.101803  121.101803
# 1               Zootopia        2016   150.0  341.268248  191.268248
# 2                   Lion        2016    12.0   51.738905   39.738905
# 3                Arrival        2016    47.0  100.546139   53.546139
# 4  Manchester by the Sea        2016     9.0   47.695371   38.695371
#
#        actor_1_name        actor_2_name     actor_3_name  \
# 0      Ryan Gosling          Emma Stone       Amiée Conn
# 1  Ginnifer Goodwin       Jason Bateman       Idris Elba
# 2         Dev Patel       Nicole Kidman      Rooney Mara
# 3         Amy Adams       Jeremy Renner  Forest Whitaker
# 4     Casey Affleck  Michelle Williams     Kyle Chandler
#
#    actor_1_facebook_likes  actor_2_facebook_likes  ...  Votes3044M  \
# 0                   14000                 19000.0  ...         7.9
# 1                    2800                 28000.0  ...         7.8
# ...

# %%
top_ten_movies=movies.sort_values(by='profit',ascending=False)

# %%
top_ten_movies=top_ten_movies.iloc[:10]

# %%
top_ten_movies
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross      profit       actor_1_name       actor_2_name  \
# 97  936.662225  691.662225        Doug Walker         Rob Walker
# 11  623.279547  403.279547    Chris Hemsworth  Robert Downey Jr.
# ...

# %%
#plottibg the scatter betweeen Prfoit and budget
plt.scatter(movies.budget,movies.profit,alpha=1)
plt.title("Profit vs Budget of Movies",c='r',fontdict={'fontsize':20})
plt.xlabel("Budget")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %%
#plotting the jointplot between Proit and Budget
import seaborn as sns
sns.jointplot(movies.budget,movies.profit)
plt.xlabel("Budget --->")
plt.ylabel("Profit --->")
plt.show()
# Out:
# C:\Users\Bijoy\anaconda3\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observation**
# High bugdet movie are are also in negative profit
# Most movie lis in 0 to 50M$ budget
# The dataset contains the 100 best performing movies from the year 2010 to 2016. However scatter plot tells a different story. You can notice that there are some movies with negative profit. Although good movies do incur losses, but there appear to be quite a few movie with losses. What can be the reason behind this? Lets have a closer look at this by finding the movies with negative profit.

# %% [markdown]
# **Extract the movies with a Negative Profit and store them in a new moviesframe - `neg_profit`"**

# %%
#Checking the negative profit movies
neg_profit=movies[movies.profit<0]

# %%
#sorting the dataframe by Profit column
neg_profit.sort_values('profit')
# Out:
#                           Title  title_year  budget       Gross     profit  \
# 22                         Hugo        2011   170.0   73.820094 -96.179906
# 39            The Little Prince        2015    81.2    1.339152 -79.860848
# 17             Edge of Tomorrow        2014   178.0  100.189501 -77.810499
# 7                       Tangled        2010   260.0  200.807262 -59.192738
# 46  Scott Pilgrim vs. the World        2010    60.0   31.494270 -28.505730
# 28           X-Men: First Class        2011   160.0  146.405371 -13.594629
# 82                      Flipped        2010    14.0    1.752214 -12.247786
# 66                      Warrior        2011    25.0   13.651662 -11.348338
# 56                         Rush        2013    38.0   26.903709 -11.096291
# 89                        Amour        2012     8.9    0.225377  -8.674623
# 99      Tucker and Dale vs Evil        2010     5.0    0.223838  -4.776162
#
# ...

# %%
neg_profit[(neg_profit['Title']=='Tangled')]
# Out:
#      Title  title_year  budget       Gross     profit  actor_1_name  \
# 7  Tangled        2010   260.0  200.807262 -59.192738  Brad Garrett
#
#    actor_2_name actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 7  Donna Murphy  M.C. Gainey                     799                   553.0
#
#    ...  Votes3044M  Votes3044F Votes45A Votes45AM Votes45AF  Votes1000  \
# 7  ...         7.5         8.0      7.7       7.6       7.9        6.9
#
#    VotesUS  VotesnUS  content_rating  Country
# 7      7.9       7.7              PG      USA
#
# [1 rows x 63 columns]

# %% [markdown]
# ** The General Audience and the Critics**

# %%
# MetaCritic  converting scale 100 to 10

# %%
movies.MetaCritic=movies.MetaCritic.apply(lambda x: (x/10))

# %%
movies.MetaCritic
# Out:
# 0     9.3
# 1     7.8
# 2     6.9
# 3     8.1
# 4     9.6
#      ...
# 95    8.8
# 96    9.4
# 97    8.1
# 98    6.5
# 99    6.5
# Name: MetaCritic, Length: 100, dtype: float64

# %%
movies['IMDb_rating']
# Out:
# 0     8.2
# 1     8.1
# 2     8.1
# 3     8.0
# 4     7.9
#      ...
# 95    8.5
# 96    7.9
# 97    8.1
# 98    7.7
# 99    7.6
# Name: IMDb_rating, Length: 100, dtype: float64

# %%
numerics = ['int16', 'int32', 'int64','float']
num=movies.select_dtypes(include=numerics)
num
# Out:
#     title_year  budget       Gross      profit  actor_1_facebook_likes  \
# 0         2016    30.0  151.101803  121.101803                   14000
# 1         2016   150.0  341.268248  191.268248                    2800
# 2         2016    12.0   51.738905   39.738905                   33000
# 3         2016    47.0  100.546139   53.546139                   35000
# 4         2016     9.0   47.695371   38.695371                     518
# ..         ...     ...         ...         ...                     ...
# 95        2014     3.3   13.092000    9.792000                   24000
# 96        2013     3.0    8.114507    5.114507                     140
# 97        2015   245.0  936.662225  691.662225                     131
# 98        2010   150.0  296.347721  146.347721                   10000
# 99        2010     5.0    0.223838   -4.776162                     948
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  MetaCritic  \
# ...

# %%
movies.iloc[:,[11,14,-1]]
# Out:
#     IMDb_rating  genre_3    Country
# 0           8.2    Music        USA
# 1           8.1   Comedy        USA
# 2           8.1      NaN  Australia
# 3           8.0   Sci-Fi        USA
# 4           7.9      NaN        USA
# ..          ...      ...        ...
# 95          8.5      NaN        USA
# 96          7.9      NaN        USA
# 97          8.1  Fantasy        USA
# 98          7.7  Fantasy         UK
# 99          7.6      NaN     Canada
#
# [100 rows x 3 columns]

# %% [markdown]
# **Creating an  Average Rating Column**

# %%
#creating the avg column by adding  the IMDB and metacritic columns
movies['Avg_rating']=(abs(movies['IMDb_rating']+movies.MetaCritic)/2)

# %%
# Sort in descending order of average rating,
movies=movies.sort_values("Avg_rating",ascending = False)

# %%
movies
# Out:
#                                 Title  title_year  budget       Gross  \
# 94                            Boyhood        2014     4.0   25.359200
# 69                   12 Years a Slave        2013    20.0   56.667870
# 18                         Inside Out        2015   175.0  356.454367
# 0                          La La Land        2016    30.0  151.101803
# 12                        Toy Story 3        2010   200.0  414.984497
# ..                                ...         ...     ...         ...
# 16  The Hobbit: An Unexpected Journey        2012   180.0  303.001229
# 88                         About Time        2013    12.0   15.294553
# 82                            Flipped        2010    14.0    1.752214
# 71                     The Book Thief        2013    19.0   21.483154
# 52                      Lone Survivor        2013    40.0  125.069696
#
#         profit        actor_1_name       actor_2_name    actor_3_name  \
# ...

# %%
# Find the movies with metacritic-Imdb rating < 0.5 and also with an average rating of >= 8 (sorted in descending order)
UniversalAcclaim=movies[(abs(movies.MetaCritic-movies['IMDb_rating']) <0.5) & (movies['IMDb_rating']>8)]

# %%
UniversalAcclaim
# Out:
#                                          Title  title_year  budget  \
# 95                                    Whiplash        2014     3.3
# 35                            Django Unchained        2012   100.0
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 43                                   Gone Girl        2014    61.0
# 1                                     Zootopia        2016   150.0
#
#          Gross      profit       actor_1_name     actor_2_name  \
# 95   13.092000    9.792000       J.K. Simmons  Melissa Benoist
# 35  162.804648   62.804648  Leonardo DiCaprio  Christoph Waltz
# 97  936.662225  691.662225        Doug Walker       Rob Walker
# 43  167.735396  106.735396      Patrick Fugit        Sela Ward
# 1   341.268248  191.268248   Ginnifer Goodwin    Jason Bateman
#
#          actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  ...  \
# 95       Chris Mulkey                   24000                   970.0  ...
# ...

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'profit', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country', 'Avg_rating'],
# ...

# %%
movies['actor_1_name'].unique()
# Out:
# array(['Ellar Coltrane', 'QuvenzhanÃ© Wallis', 'Amy Poehler',
#        'Ryan Gosling', 'Tom Hanks', 'Casey Affleck', 'Phaldut Sharma',
#        'Billy Crudup', 'Seamus Davey-Fitzpatrick', 'J.K. Simmons',
#        'Isabelle Huppert', 'Andrew Garfield', 'Tom Hardy',
#        'Scarlett Johansson', 'Bill Murray', 'BÃ©rÃ©nice Bejo',
#        'Colin Firth', 'Emma Stone', 'Leonardo DiCaprio', 'Chris Pine',
#        'Matthew McConaughey', 'Devin Ratray', 'Clea DuVall',
#        'Philip Seymour Hoffman', 'Bruce Willis', 'Doug Walker',
#        'Amy Adams', 'Morgan Freeman', 'Patrick Fugit', 'Matt Damon',
#        'Natalie Portman', 'Albert Finney', 'Ginnifer Goodwin',
#        'Jennifer Lawrence', 'Kurt Fuller', 'ChloÃ« Grace Moretz',
#        'Edgar Arreola', 'Sylvester Stallone', 'James Franco',
#        'Christian Bale', 'Bradley Cooper', 'Chris Hemsworth',
#        'Elina Alminas', 'Jake Gyllenhaal', 'Hugh Jackman', 'Gary Oldman',
# ...

# %% [markdown]
# **Subtask 2.4: Find the Most Popular Trios**

# %%
movies['fb_like_actor']=movies['actor_1_facebook_likes']+movies['actor_2_facebook_likes']+movies['actor_3_facebook_likes']

# %%
movies_actor_top_5=movies.sort_values('fb_like_actor',ascending=False,).head(5)

# %%
movies_actor_top_5.loc[:,['actor_1_name','actor_2_name','actor_3_name']]
# Out:
#          actor_1_name        actor_2_name          actor_3_name
# 2           Dev Patel       Nicole Kidman           Rooney Mara
# 27  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 14  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 4       Casey Affleck  Michelle Williams          Kyle Chandler
# 8           Tom Hardy      Christian Bale  Joseph Gordon-Levitt

# %%
movies_actor_top_5.iloc[:,[8,9,10]]
# Out:
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes
# 2                    33000                 96000.0                  9800.0
# 27                   29000                 27000.0                 23000.0
# 14                   34000                 22000.0                 20000.0
# 4                      518                 71000.0                  3300.0
# 8                    27000                 23000.0                 23000.0

# %% [markdown]
# ** Find the Most Popular Trios**

# %%
# Manually inspecting the condition

# %%
movies_actor_top_5.iloc[:,[0,5,6,7,8,9,10,-1]]
# Out:
#                          Title       actor_1_name        actor_2_name  \
# 2                         Lion          Dev Patel       Nicole Kidman
# 27                   Inception  Leonardo DiCaprio           Tom Hardy
# 14  X-Men: Days of Future Past  Jennifer Lawrence      Peter Dinklage
# 4        Manchester by the Sea      Casey Affleck  Michelle Williams
# 8        The Dark Knight Rises          Tom Hardy      Christian Bale
#
#             actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 2            Rooney Mara                   33000                 96000.0
# 27  Joseph Gordon-Levitt                   29000                 27000.0
# 14          Hugh Jackman                   34000                 22000.0
# 4          Kyle Chandler                     518                 71000.0
# 8   Joseph Gordon-Levitt                   27000                 23000.0
#
#     actor_3_facebook_likes  fb_like_actor
# 2                   9800.0       138800.0
# ...

# %% [markdown]
#  **No. of trios that satisfy the above condition:`** ==  3  {inception, Xmen , The dark knight rises}
#
#  **Most popular trio after applying the condition: ['Leonardo DiCaprio','Tom Hardy','Joseph Gordon-Levitt']

# %%
movies['actor_1_facebook_likes']+movies['actor_2_facebook_likes']+movies['actor_2_facebook_likes']
# Out:
# 94      616.0
# 69     3320.0
# 18     2534.0
# 0     52000.0
# 12    17000.0
#        ...
# 16     6944.0
# 88     1675.0
# 82     2744.0
# 71     1928.0
# 52     1378.0
# Length: 100, dtype: float64

# %%
movies_fbc=movies.iloc[:,[8,9,10,-2]]
movies_fbc
# Out:
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 94                     230                   193.0                   127.0
# 69                    2000                   660.0                   500.0
# 18                    1000                   767.0                   384.0
# 0                    14000                 19000.0                     0.0
# 12                   15000                  1000.0                   721.0
# ..                     ...                     ...                     ...
# 16                    5000                   972.0                   773.0
# 88                     565                   555.0                   171.0
# 82                    1000                   872.0                   767.0
# 71                     876                   526.0                   326.0
# 52                     480                   449.0                   127.0
#
#     fb_like_actor
# 94          550.0
# 69         3160.0
# ...

# %%
movies_fbc.dtypes
# Out:
# actor_1_facebook_likes      int64
# actor_2_facebook_likes    float64
# actor_3_facebook_likes    float64
# dtype: object

# %% [markdown]
# ** Runtime Analysis**

# %%
movies.Runtime
# Out:
# 94    165
# 69    134
# 18     95
# 0     128
# 12    103
#      ...
# 16    169
# 88    123
# 82    124
# 71    131
# 52    121
# Name: Runtime, Length: 100, dtype: int64

# %%
import seaborn as sns
sns.distplot(movies.Runtime)
plt.show()
# Out:
# C:\Users\Bijoy\anaconda3\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Checkpoint 3: Most of the movies appear to be sharply 2 hour-long.

# %% [markdown]
# ** R-Rated Movies**

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'profit', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
# ...

# %%
PopularR=movies[movies['content_rating']=='R']

# %%
PopularR.sort_values('CVotesU18',ascending=False,)
# Out:
#                                               Title  title_year  budget  \
# 47                                         Deadpool        2016    58.0
# 36                          The Wolf of Wall Street        2013   100.0
# 35                                 Django Unchained        2012   100.0
# 29                               Mad Max: Fury Road        2015   150.0
# 95                                         Whiplash        2014     3.3
# 31                                     The Revenant        2015   135.0
# 40                                   Shutter Island        2010    80.0
# 43                                        Gone Girl        2014    61.0
# 65                         The Grand Budapest Hotel        2014    25.0
# 72  Birdman or (The Unexpected Virtue of Ignorance)        2014    18.0
# 69                                 12 Years a Slave        2013    20.0
# 68                          Silver Linings Playbook        2012    21.0
# ...

# %% [markdown]
# # Demographic Analysis

# %% [markdown]
# ** Combine the Dataframe by Genres**

# %%
movies.genre_3
# Out:
# 94        NaN
# 69    History
# 18     Comedy
# 0       Music
# 12     Comedy
#        ...
# 16        NaN
# 88    Fantasy
# 82    Romance
# 71        NaN
# 52      Drama
# Name: genre_3, Length: 100, dtype: object

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'profit', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
# ...

# %%
df_by_genre=movies[['genre_1', 'genre_2', 'genre_3',  'CVotes10','CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04','CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
       'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
       'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
       'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
       'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
       'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
       'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
       'VotesnUS']]

# %%
# Create a column cnt and initialize it to 1
df_by_genre['cnt']=1
# Out:
# <ipython-input-63-fa255747ffdc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_by_genre['cnt']=1

# %%
df_by_genre
# Out:
#       genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 94      Drama        NaN      NaN     49673     62055     76838     52238
# 69  Biography      Drama  History     75556    126223    161460     83070
# 18  Animation  Adventure   Comedy     87509    113244    119801     67153
# 0      Comedy      Drama    Music     74245     71191     64640     38831
# 12  Animation  Adventure   Comedy    139773    149992    158704     88289
# ..        ...        ...      ...       ...       ...       ...       ...
# 16  Adventure    Fantasy      NaN    135848    132202    191128    122538
# 88     Comedy      Drama  Fantasy     38556     43170     70850     45487
# 82     Comedy      Drama  Romance     11354     11050     20808     14372
# 71      Drama        War      NaN     15911     17607     32570     24461
# 52     Action  Biography    Drama     30856     33356     68808     54195
#
#     CVotes06  CVotes05  CVotes04  ...  Votes3044  Votes3044M  Votes3044F  \
# ...

# %%
# Group the movies by individual genres

# %%
df_by_g1=df_by_genre.groupby(by='genre_1').sum()

# %%
df_by_g2=df_by_genre.groupby(by='genre_2').sum()

# %%
df_by_g3=df_by_genre.groupby(by='genre_3').sum()

# %%
# Add the grouped data frames and store it in a new data frame

# %%
df_add=df_by_g1.add(df_by_g2,fill_value=0).add(df_by_g3,fill_value=0)

# %%
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %% [markdown]
# **Extract genres with atleast 10 occurences**

# %%
genre_top10=df_add[df_add.cnt>10]

# %%
genre_top10=pd.concat([genre_top10.iloc[:,0:43].div(genre_top10.cnt,axis=0),genre_top10.cnt],axis=1)
#Take the mean for every column by dividing with cnt

# %%
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
genre_top10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Action to Thriller
# Data columns (total 44 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CVotes10      10 non-null     float64
#  1   CVotes09      10 non-null     float64
#  2   CVotes08      10 non-null     float64
#  3   CVotes07      10 non-null     float64
#  4   CVotes06      10 non-null     float64
#  5   CVotes05      10 non-null     float64
#  6   CVotes04      10 non-null     float64
#  7   CVotes03      10 non-null     float64
#  8   CVotes02      10 non-null     float64
#  9   CVotes01      10 non-null     float64
#  10  CVotesMale    10 non-null     float64
#  11  CVotesFemale  10 non-null     float64
#  12  CVotesU18     10 non-null     float64
#  13  CVotesU18M    10 non-null     float64
#  14  CVotesU18F    10 non-null     float64
#  15  CVotes1829    10 non-null     float64
#  16  CVotes1829M   10 non-null     float64
# ...

# %%
a34=genre_top10.iloc[:,27:].round(2)# Rounding off the columns of Votes to two decimals

# %%
a1=genre_top10.iloc[:,0:26].astype("int")# Converting CVotes to int type

# %%
genre_top10=pd.concat([a1,a34],axis=1)

# %%
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes1829F  Votes3044  \
# Action         5386      3064      2115      5524  ...        8.00       7.74
# ...

# %% [markdown]
# **Genre Counts!**

# %% [markdown]
#  Chart Plotting different -genres vs cnt using seaborn-

# %%
genre_top10.index.name='genre'

# %%
sns.barplot(x=genre_top10.index,y=genre_top10.cnt)
plt.title("Genres vs cnt")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# #Checkpoint 5: Is the bar for Drama the tallest

# %%
genre_top10.index
# Out:
# Index(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
#        'Drama', 'Romance', 'Sci-Fi', 'Thriller'],
#       dtype='object', name='genre')

# %%
# as per observation Drama had  tallest peak .

# %% [markdown]
# ** Gender and Genre**

# %%
genre_top10.loc[:,['CVotesU18M','CVotes1829M','CVotes3044M','CVotes45AM']]
# Out:
#            CVotesU18M  CVotes1829M  CVotes3044M  CVotes45AM
# genre
# Action           1916       164703       132836       24092
# Adventure        1900       146808       115795       21910
# Animation        1486       103695        75824       12966
# Biography         886       114043        92158       18039
# Comedy           1178       109016        86346       15979
# Crime             932       122690       102671       18799
# Drama             915       105203        87644       17422
# Romance           535        79024        62253       12054
# Sci-Fi           2382       197123       160141       30141
# Thriller         1327       156573       129421       24421

# %% [markdown]
# **1st set of heat maps for CVotes-related columns**

# %%
f,(ax1,ax2) =plt.subplots(1,2,figsize=(18, 8),sharey=True)
sns.heatmap(data=genre_top10[['CVotesU18M','CVotes1829M','CVotes3044M','CVotes45AM']],cmap="Set2_r",annot=True,linewidth=1,ax=ax1,fmt='d')
sns.heatmap(data= genre_top10[['CVotesU18F','CVotes1829F', 'CVotes3044F', 'CVotes45AF']],cmap='Set1_r',annot=True,linewidth=0.5,fmt='d')
# Out:
# <AxesSubplot:ylabel='genre'>

# %%
# # we can see female cast more votes tgan male
# Observation 1= Sci Fi is most common among the 18 to 29 age group
# Observation 2= U18m romance is least liked movie while U18f crime movie is least liked
# Observation  3= U1829M and 3044M  shows simmilar type of respose while not in case of Female

# %% [markdown]
# **2nd set of heat maps for Votes-related columns**

# %%
f,(ax3,ax4)= plt.subplots(1,2,figsize =(18,8),sharey = True)
sns.heatmap(data=genre_top10[['VotesU18M','Votes1829M','Votes3044M','Votes45AM']],cmap="Blues",annot=True,linewidth=1,ax=ax3)
sns.heatmap(data=genre_top10[['VotesU18F','Votes1829F','Votes3044F','Votes45AF']],cmap='Greens',annot=True,linewidth=1,ax=ax4)
# Out:
# <AxesSubplot:ylabel='genre'>

# %%
# Inference three inferences,
#     "- Observation 1:U18M  more interested in crime movies as compare tp female 
#     "- Observaton 2:U18F & U1829F more interested in animation 
#     "- Observaton 3:U3044F not interested in crime

# %%
genre_top10.columns
# Out:
# Index(['CVotes10', 'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05',
#        'CVotes04', 'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale',
#        'CVotesFemale', 'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829',
#        'CVotes1829M', 'CVotes1829F', 'CVotes3044', 'CVotes3044M',
#        'CVotes3044F', 'CVotes45A', 'CVotes45AM', 'CVotes45AF', 'CVotes1000',
#        'CVotesUS', 'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F',
#        'Votes1829', 'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M',
#        'Votes3044F', 'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000',
#        'VotesUS', 'cnt'],
#       dtype='object')

# %% [markdown]
# ** US vs non-US Cross Analysis***

# %%
# Creating IFUS column(weather the movies is us or not )

# %%
movies.Country.unique()
# Out:
# array(['USA', 'UK', 'France', 'Australia', 'Spain', 'Canada'],
#       dtype=object)

# %%
movies['IFUS']=movies.Country.apply(lambda x :x if x =='USA'     else "Non-USA")

# %%
movies
# Out:
#                                 Title  title_year  budget       Gross  \
# 94                            Boyhood        2014     4.0   25.359200
# 69                   12 Years a Slave        2013    20.0   56.667870
# 18                         Inside Out        2015   175.0  356.454367
# 0                          La La Land        2016    30.0  151.101803
# 12                        Toy Story 3        2010   200.0  414.984497
# ..                                ...         ...     ...         ...
# 16  The Hobbit: An Unexpected Journey        2012   180.0  303.001229
# 88                         About Time        2013    12.0   15.294553
# 82                            Flipped        2010    14.0    1.752214
# 71                     The Book Thief        2013    19.0   21.483154
# 52                      Lone Survivor        2013    40.0  125.069696
#
#         profit        actor_1_name       actor_2_name    actor_3_name  \
# ...

# %%
movies_USA=movies[movies.IFUS=='USA']

# %%
# Box plot - 1: CVotesUS(y) vs IFUS(x)
f,(ax1,ax2)=plt.subplots(1,2,figsize=(10,8),sharey=True)
sns.boxplot(data=movies, x="IFUS",y= 'CVotesUS',ax=ax1)
sns.boxplot(data=movies ,x='IFUS', y='CVotesnUS',ax=ax2)
# Out:
# <AxesSubplot:xlabel='IFUS', ylabel='CVotesnUS'>

# %%
# # obsevation
# 1 It is observe that nonUS people cast more vote than Us 
# 2 less deviation in UScvotes  than nonUS cvotes

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'profit', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
# ...

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)
f,(ax1,ax2)=plt.subplots(1,2,figsize=(10,8),sharex=True)
sns.boxplot(data=movies,x='IFUS',y='VotesUS',ax=ax1)
sns.boxplot(data=movies,x='IFUS',y='VotesnUS',ax=ax2)
# Out:
# <AxesSubplot:xlabel='IFUS', ylabel='VotesnUS'>

# %%
# observation
# 1- Average rating of Us  movies  by USvotes is higher than NonUS movies
# 2- NonUS people rated US movie better than nonUS movies
# 3- USvotes show more deviation in USA movies & nonUS votes show more deviation in NonUSA movies

# %% [markdown]
# **Top 1000 Voters Vs Genres**

# %% [markdown]
# You might have also observed the column CVotes1000. This column represents the top 1000 voters on IMDb and gives the count for the number of these voters who have voted for a particular movie. Let's see how these top 1000 voters have voted across the genres.
#
# Sort the dataframe genre_top10 based on the value of CVotes1000in a descending order.
#
# Make a seaborn barplot for genre vs CVotes1000.
#
# Write your inferences. You can also try to relate it with the heatmaps you did in the previous subtasks.

# %%
genre_top10.columns
# Out:
# Index(['CVotes10', 'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05',
#        'CVotes04', 'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale',
#        'CVotesFemale', 'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829',
#        'CVotes1829M', 'CVotes1829F', 'CVotes3044', 'CVotes3044M',
#        'CVotes3044F', 'CVotes45A', 'CVotes45AM', 'CVotes45AF', 'CVotes1000',
#        'CVotesUS', 'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F',
#        'Votes1829', 'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M',
#        'Votes3044F', 'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000',
#        'VotesUS', 'cnt'],
#       dtype='object')

# %%
genre_top10.CVotes1000
# Out:
# genre
# Action       681
# Adventure    662
# Animation    578
# Biography    600
# Comedy       605
# Crime        620
# Drama        585
# Romance      548
# Sci-Fi       714
# Thriller     669
# Name: CVotes1000, dtype: int32

# %%
#sorting the genre_top10 by sort values
genre_top10=genre_top10.sort_values('CVotes1000',ascending = False)

# %%
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Action       102144    114433    150895     94262     34688     12693
# Thriller      83207    112730    153336     90446     32003     11534
# Adventure     94596    105636    138482     86367     31896     11551
# Crime         52229     87919    129045     74671     25308      8971
# Comedy        60157     77173    108993     69176     26099      9863
# Biography     47333     77867    123948     74054     23644      7702
# Drama         52375     75928    109339     66456     23528      8497
# Animation     61960     72566    104837     65707     22825      7551
# Romance       42304     53037     82252     54833     21637      8530
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes1829F  Votes3044  \
# genre                                              ...
# ...

# %%
#bar plot  between CVotes1000 and gerne
sns.barplot(y=genre_top10.CVotes1000,x=genre_top10.index)
plt.title("Top 1000 Voters Vs Genres")
plt.xticks(rotation=60)
plt.show()

# %%
# observation
# 1 Most popular movies Sci-Fi. As we see in the heatmap age group  18-27
# 2.Least poupular movie is Romance . from heatmap we can also say that female cast more vote to romantic movies
# 3.Sci-fi , action, thriller ,adventure   above mean value

# %%
genre_top10.CVotes1000.mean()
# Out:
# 626.2
